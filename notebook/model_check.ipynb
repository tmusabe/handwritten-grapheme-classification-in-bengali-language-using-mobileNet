# %%
import torch
import sys
sys.path.append("../")
from models import MobileNetV2
from torch.nn import functional as F

# %%
model = MobileNetV2(pretrained=False)
# Out:
# Using cache found in /home/musabeta/.cache/torch/hub/pytorch_vision_v0.10.0

# %%
model
# Out:
# MobileNetV2(
#   (model): MobileNetV2(
#     (features): Sequential(
#       (0): ConvBNActivation(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNActivation(
# ...

# %%
x = torch.ones([3, 128, 128], dtype=torch.float32)
x = x.unsqueeze(0)
print(x.shape)
# Out:
# torch.Size([1, 3, 128, 128])

# %%
y = F.adaptive_avg_pool2d(model.model.features(x), 1)
print(y.shape)
# Out:
# torch.Size([1, 1280, 1, 1])

# %%
y
# Out:
# tensor([[[[0.4117]],
#
#          [[0.3347]],
#
#          [[0.4168]],
#
#          ...,
#
#          [[0.3680]],
#
#          [[0.4398]],
#
#          [[0.3951]]]], grad_fn=<MeanBackward1>)
